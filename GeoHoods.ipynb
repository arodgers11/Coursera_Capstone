# %% [markdown]
# ## LeBronto Neighborhoods
# ### Andrew Rodgers
# Import all the necessary modules and make scrape the data from the webpage

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

resp = requests.get(url=url)

soup = BeautifulSoup(resp.text,"html.parser")

table = soup.findAll('table')[0]

# %% [markdown]
# Format the html to list, one for the header and another for the data

# %%
header = []
data = []
for i in table.findAll('tr'):
    for j in i.findAll('th'):
        header.append(j.text)
    for j in i.findAll('td'):
        data.append(j.text)

# %% [markdown]
# Format the header and data lists into a *pandas* dataframe, **df**

# %%
header[2] = header[2][0:-1]
col1 = []
col2 = []
col3 = []
for i in range(0,len(data),3):
    col1.append(data[i])
    col2.append(data[i+1])
    col3.append(data[i+2])
    
df = pd.DataFrame(list(zip(col1,col2,col3)),columns = header)

# %% [markdown]
# Subset **df** so we only use the rows with assigned Boroughs
# Use the Borough for the neighborhood name if not assigned

# %%
df = df[df.Borough != 'Not assigned']

for i in range(0,len(df['Postcode'])):
    if "\n" in df.iloc[i,2]:
        df.iloc[i,2] = df.iloc[i,2][0:-1]
    if df.iloc[i,2] == "Not assigned":
        df.iloc[i,2] = df.iloc[i,1]

# %% [markdown]
# Sort **df** by Postcode to make searchign easier
# Loop through **df** to combine neighborhoods in the same cell, separated by commas

# %%
df = df.sort_values('Postcode',0)

for i in range(0,len(df['Postcode'])):
    if df.iloc[i-1,0] == df.iloc[i,0]:
        #if df.iloc[i-1,2] in df.iloc[i,2]:
        df.iloc[i,2] = df.iloc[i-1,2] + ", " + df.iloc[i,2]
        
df = df.drop_duplicates(subset='Postcode', keep='last', inplace=False)

# %% [markdown]
# Here's a sample of **df**

# %%
df.head()
# Out:
#    Postcode      Borough                           Neighbourhood
# 12      M1B  Scarborough                          Rouge, Malvern
# 27      M1C  Scarborough  Port Union, Rouge Hill, Highland Creek
# 44      M1E  Scarborough       Guildwood, Morningside, West Hill
# 53      M1G  Scarborough                                  Woburn
# 62      M1H  Scarborough                               Cedarbrae

# %%
df.shape
# Out:
# (103, 3)

# %%
geo = pd.read_csv("http://cocl.us/Geospatial_data")

# %%
df['Latitude'] = geo['Latitude']
df['Longitude'] = geo['Longitude']

# %%
lat = []
long = []
for i in df['Postcode']:
    lat.append(float(geo.loc[geo['Postal Code']==i]['Latitude']))
    long.append(float(geo.loc[geo['Postal Code']==i]['Longitude']))
    
df['Latitude'] = lat
df['Longitude'] = long

# %%
df
# Out:
#     Postcode           Borough  \
# 12       M1B       Scarborough
# 27       M1C       Scarborough
# 44       M1E       Scarborough
# 53       M1G       Scarborough
# 62       M1H       Scarborough
# 76       M1J       Scarborough
# 93       M1K       Scarborough
# 107      M1L       Scarborough
# 124      M1M       Scarborough
# 140      M1N       Scarborough
# 152      M1P       Scarborough
# 165      M1R       Scarborough
# 180      M1S       Scarborough
# 193      M1T       Scarborough
# 208      M1V       Scarborough
# 236      M1W       Scarborough
# 246      M1X       Scarborough
# 63       M2H        North York
# 78       M2J        North York
# 94       M2K        North York
# 111      M2L        North York
# 126      M2M        North York
# 142      M2N        North York
# 154      M2P        North York
# 166      M2R        North York
# 2        M3A        North York
# 14       M3B        North York
# 31       M3C        North York
# 64       M3H        North York
# 81       M3J        North York
# ..       ...               ...
# 35       M6C              York
# 49       M6E              York
# 58       M6G  Downtown Toronto
# 72       M6H      West Toronto
# 86       M6J      West Toronto
# 103      M6K      West Toronto
# 119      M6L        North York
# 132      M6M              York
# 147      M6N              York
# 160      M6P      West Toronto
# 172      M6R      West Toronto
# 187      M6S      West Toronto
# 8        M7A      Queen's Park
# 174      M7R       Mississauga
# 265      M7Y      East Toronto
# 225      M8V         Etobicoke
# 243      M8W         Etobicoke
# 255      M8X         Etobicoke
# 268      M8Y         Etobicoke
# 285      M8Z         Etobicoke
# 10       M9A         Etobicoke
# 23       M9B         Etobicoke
# 38       M9C         Etobicoke
# 122      M9L        North York
# 138      M9M        North York
# 150      M9N              York
# 163      M9P         Etobicoke
# 177      M9R         Etobicoke
# 233      M9V         Etobicoke
# 245      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 12                                      Rouge, Malvern  43.806686 -79.194353
# 27              Port Union, Rouge Hill, Highland Creek  43.784535 -79.160497
# 44                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 53                                              Woburn  43.770992 -79.216917
# 62                                           Cedarbrae  43.773136 -79.239476
# 76                                 Scarborough Village  43.744734 -79.239476
# 93         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 107                    Golden Mile, Oakridge, Clairlea  43.711112 -79.284577
# 124    Cliffcrest, Scarborough Village West, Cliffside  43.716316 -79.239476
# 140                        Cliffside West, Birch Cliff  43.692657 -79.264848
# 152  Wexford Heights, Dorset Park, Scarborough Town...  43.757410 -79.273304
# 165                                  Maryvale, Wexford  43.750072 -79.295849
# 180                                          Agincourt  43.794200 -79.262029
# 193            Sullivan, Clarks Corners, Tam O'Shanter  43.781638 -79.304302
# 208  Milliken, Agincourt North, L'Amoreaux East, St...  43.815252 -79.284577
# 236                                    L'Amoreaux West  43.799525 -79.318389
# 246                                        Upper Rouge  43.836125 -79.205636
# 63                                   Hillcrest Village  43.803762 -79.363452
# 78                        Fairview, Oriole, Henry Farm  43.778517 -79.346556
# 94                                     Bayview Village  43.786947 -79.385975
# 111                           Silver Hills, York Mills  43.757490 -79.374714
# 126                            Willowdale, Newtonbrook  43.789053 -79.408493
# 142                                   Willowdale South  43.770120 -79.408493
# 154                                    York Mills West  43.752758 -79.400049
# 166                                    Willowdale West  43.782736 -79.442259
# 2                                            Parkwoods  43.753259 -79.329656
# 14                                     Don Mills North  43.745906 -79.352188
# 31                    Don Mills South, Flemingdon Park  43.725900 -79.340923
# 64     Wilson Heights, Downsview North, Bathurst Manor  43.754328 -79.442259
# 81                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 35                                  Humewood-Cedarvale  43.693781 -79.428191
# 49                                 Caledonia-Fairbanks  43.689026 -79.453512
# 58                                            Christie  43.669542 -79.422564
# 72                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 86                            Trinity, Little Portugal  43.647927 -79.419750
# 103       Exhibition Place, Brockton, Parkdale Village  43.636847 -79.428191
# 119                 North Park, Downsview, Upwood Park  43.713756 -79.490074
# 132     Silverthorn, Mount Dennis, Keelesdale, Del Ray  43.691116 -79.476013
# 147                      The Junction North, Runnymede  43.673185 -79.487262
# 160                      High Park, The Junction South  43.661608 -79.464763
# 172                             Roncesvalles, Parkdale  43.648960 -79.456325
# 187                                 Runnymede, Swansea  43.651571 -79.484450
# 8                                         Queen's Park  43.662301 -79.389494
# 174              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 265  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 225       Mimico South, New Toronto, Humber Bay Shores  43.605647 -79.501321
# 243                             Long Branch, Alderwood  43.602414 -79.543484
# 255      Old Mill North, Montgomery Road, The Kingsway  43.653654 -79.506944
# 268  Old Mill South, King's Mill Park, Humber Bay, ...  43.636258 -79.498509
# 285  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 10                                    Islington Avenue  43.667856 -79.532242
# 23   Cloverdale, West Deane Park, Princess Gardens,...  43.650943 -79.554724
# 38   Old Burnhamthorpe, Markland Wood, Eringate, Bl...  43.643515 -79.577201
# 122                                      Humber Summit  43.756303 -79.565963
# 138                                   Humberlea, Emery  43.724766 -79.532242
# 150                                             Weston  43.706876 -79.518188
# 163                                          Westmount  43.696319 -79.532242
# 177  Richview Gardens, Kingsview Village, St. Phill...  43.688905 -79.554724
# 233  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 245                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]
